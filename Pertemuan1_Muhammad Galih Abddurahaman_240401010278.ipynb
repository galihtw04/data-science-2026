# %% [markdown]
# # Pertemuan 1
# Nama : Muhammad Galih Abdurrahman
#
# NIM : 240401010278
#
# Kelas IF403

# %%
# SEL 1: Output sederhana
print ("Hello, Data Science!")

#SEL 2: Variabel & tipe data
nama = "Muhammad Galih Abdurrahman"
prodi = "PJJ Informatika"
angkatan = 2024
print(f"Halo, {nama} mahasiswa {prodi} angkatan {angkatan}!")

#SEL 3: List & perulangan
tools = ["Python", "Colab", "Jupyter", "Github"]
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")

# SEL 4: Fungsi python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Galih", "Informatika", 2024))
# Out:
# Hello, Data Science!
# Halo, Muhammad Galih Abdurrahman mahasiswa PJJ Informatika angkatan 2024!
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. Github
# Galih | Informatika | 2024

# %% [markdown]
# ## Kesimpulan
#
# Pada Pertemuan 1 ini, saya mempelajari pengenalan awal terhadap lingkungan pembelajaran Data Science, khususnya penggunaan Python, Jupyter Notebook atau Google Colab, serta GitHub sebagai media dokumentasi dan penyimpanan hasil praktikum. Pertemuan ini menjadi dasar penting sebelum masuk ke materi pengolahan data, analisis data, visualisasi data, dan machine learning.
#
# Melalui notebook perkenalan ini, saya memahami bahwa identitas, tujuan belajar, dan dokumentasi proses pembelajaran perlu ditulis dengan jelas agar notebook lebih terstruktur dan mudah dipahami. Selain itu, penggunaan notebook membantu proses belajar karena kode program, penjelasan, dan hasil output dapat ditampilkan dalam satu file yang rapi.
#
# Temuan utama dari pertemuan ini adalah bahwa Data Science membutuhkan pemahaman dasar terhadap tools yang digunakan, bukan hanya kemampuan menulis kode. Dengan memahami cara menggunakan notebook dan GitHub, proses belajar dapat terdokumentasi dengan baik dan dapat dilihat kembali sebagai portofolio pembelajaran.
#
# Keterbatasan dari pertemuan ini adalah materi yang dibahas masih bersifat pengenalan awal dan belum masuk ke proses analisis data secara mendalam. Pertanyaan lanjutan yang muncul adalah bagaimana Python dan library Data Science seperti Pandas, NumPy, Matplotlib, dan scikit-learn digunakan untuk mengolah serta menganalisis dataset pada pertemuan berikutnya.
